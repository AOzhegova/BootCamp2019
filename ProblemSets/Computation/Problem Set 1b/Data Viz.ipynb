# %% [markdown]
# Week 1 - Data Vizualization

# %% [markdown]
# Date: 07/03/2019

# %% [markdown]
# Author: Alina Ozhegova

# %%
import numpy as np
import scipy
import math
from matplotlib import pyplot as plt
from scipy.special import binom

# %%
T = np.polynomial.Chebyshev.basis
x = np.linspace(-1, 1, 200)
for n in range(9):
    plt.plot(x, T(n)(x), label="n = "+str(n))
plt.axis([-1.1, 1.1, -1.1, 1.1])
plt.legend(loc="right")
plt.show()

# %% [markdown]
# ### Problem 2

# %%
fig, axes = plt.subplots(4, 4, sharex=True, sharey=True)
x = np.linspace(0, 1, 50)
axes[0,0].set_ylim([0,2])

for n in np.arange(0, 4, 1):
    for v in np.arange(0, n + 1, 1):
         y = scipy.special.binom(n, v) * x**(v) * (1 - x)**(n - v)
         axes[n, v].plot(x, y)

# %% [markdown]
# ### Problem 3

# %%
data = np.load('MLB.npy')
height = data[:, 0]
weight = data[:, 1]
age = data[:, 2]

# %%
data
# Out:
# array([[  74.  ,  180.  ,   22.99],
#        [  74.  ,  215.  ,   34.69],
#        [  72.  ,  210.  ,   30.78],
#        ...,
#        [  75.  ,  205.  ,   25.19],
#        [  75.  ,  190.  ,   31.01],
#        [  73.  ,  195.  ,   27.92]])

# %%
fig, ax = plt.subplots(1, 3)
ax[0].hist(height, bins = 20)
ax[0].set_title("Distribution of height")
ax[1].hist(weight, bins = 35)
ax[1].set_title("Distribution of weight")
ax[2].hist(age, bins = 35)
ax[2].set_title("Distribution of age");

# %%
fig, ax = plt.subplots(1, 3)
ax[0].scatter(height, weight, alpha = .5, edgecolor = 'none')
ax[1].scatter(height, age, alpha = .5, edgecolor = 'none')
ax[2].scatter(weight, age, alpha = .5, edgecolor = 'none');

# %%
sns.regplot(x = height, y = weight);

# %%
sns.regplot(x = height, y = age);

# %%
sns.regplot(x = weight, y = age);

# %% [markdown]
# ### Problem 5

# %%
x = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, x)
Z = (1 - X)**2 + 100 * (Y - X**2)**2

# %%
fig, ax = plt.subplots(2, 2)
ax[0,0].pcolormesh(X, Y, Z, cmap = "viridis")
ax[0,1].contour(X, Y, Z, 6, cmap = "viridis") 
ax[1,0].contourf(X, Y, Z, 12, cmap = "magma")
ax[1,1].contour(X, Y, Z, [-1, -.25, 0, .25, 1, 4], colors = "white")
cax = ax[1,1].pcolormesh(X, Y, Z, cmap="magma")
fig.colorbar(cax, ax=ax[1,1])
plt.show()

# %% [markdown]
# ### Problem 6

# %%
data = np.load('countries.npy')

# %%
population = data[:, 0]
gdp = data[:, 1]
m_height = data[:, 2]
f_height = data[:, 3]

# %%
countries = ["Austria", "Bolivia", "Brazil", "China",
    "Finland", "Germany", "Hungary", "India",
    "Japan", "North Korea", "Montenegro", "Norway",
    "Peru", "South Korea", "Sri Lanka", "Switzerland",
    "Turkey", "United Kingdom", "United States", "Vietnam"]
countries_array = np.array(countries)
#pos = np.arange(len(countries))
pos_sort = gdp.argsort()
countr_sort = countries_array[pos_sort]
gdp_sort = gdp[pos_sort]

# %%
countries_array
# Out:
# array(['Austria', 'Bolivia', 'Brazil', 'China', 'Finland', 'Germany',
#        'Hungary', 'India', 'Japan', 'North Korea', 'Montenegro', 'Norway',
#        'Peru', 'South Korea', 'Sri Lanka', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States', 'Vietnam'],
#       dtype='<U14')

# %%
plt.barh(countr_sort, gdp_sort, align = 'center')
plt.title("hh")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-195-4018a0c39f71> in <module>()
# ----> 1 plt.barh(countr_sort, gdp_sort, align = 'center')
#       2 plt.title("hh")
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in barh(bottom, width, height, left, hold, **kwargs)
#    2723                       mplDeprecation)
#    2724     try:
# -> 2725         ret = ax.barh(bottom, width, height=height, left=left, **kwargs)
#    2726     finally:
#    2727         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, bottom, width, height, left, **kwargs)
#    2283
#    2284         patches = self.bar(left=left, height=height, width=width,
# -> 2285                            bottom=bottom, orientation='horizontal', **kwargs)
#    2286         return patches
#    2287
#
# ...

# %%
population
# Out:
# array([  8.74200000e+00,   1.09850000e+01,   2.06553000e+02,
#          1.37836000e+03,   5.49500000e+00,   8.17710000e+01,
#          9.82300000e+00,   1.33009000e+03,   1.27000000e+02,
#          2.42140000e+01,   6.22000000e-01,   5.23700000e+00,
#          3.14890000e+01,   5.06170000e+01,   2.09660000e+01,
#          8.34200000e+00,   7.87420000e+01,   6.51100000e+01,
#          3.24311000e+02,   9.27000000e+01])

# %%
fig, ax = plt.subplots(1, 2)
ax[0].scatter(m_height, gdp, alpha = .5, edgecolor = 'none')
ax[0].set_title("Male height and gdp")
ax[0].set_xlabel("Male height")
ax[0].set_ylabel("GDP")
ax[1].scatter(f_height, gdp, alpha = .5, edgecolor = 'none')
ax[1].set_title("Female height and gdp")
ax[1].set_xlabel("Female height")
ax[1].set_ylabel("GDP");

# %%
fig, ax = plt.subplots(1, 2)
ax[0].hist(m_height, bins = 10)
ax[0].set_title("Distribution of male height")
ax[1].hist(f_height, bins = 10)
ax[1].set_title("Distribution of female height");

# %%
countr_sort
# Out:
# array(['Montenegro', 'Norway', 'Finland', 'Switzerland', 'Austria',
#        'Hungary', 'Bolivia', 'Sri Lanka', 'North Korea', 'Peru',
#        'South Korea', 'United Kingdom', 'Turkey', 'Germany', 'Vietnam',
#        'Japan', 'Brazil', 'United States', 'India', 'China'],
#       dtype='<U14')

# %%
countries_a = np.array(countries)
pos_pop = np.argsort(population)
pop_sort = np.arange(1, 19, 1)

sort_index = population.argsort()
pop_sort = population[sort_index]
countr_sort = countries_a[sort_index]

plt.barh(countr_sort, pop_sort)
#plt.show()
#plt.set_yticks(pop_sort, countries)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-da8fc20a06cd> in <module>()
#       7 countr_sort = countries_a[sort_index]
#       8
# ----> 9 plt.barh(countr_sort, pop_sort)
#      10 #plt.show()
#      11 #plt.set_yticks(pop_sort, countries)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in barh(bottom, width, height, left, hold, **kwargs)
#    2723                       mplDeprecation)
#    2724     try:
# -> 2725         ret = ax.barh(bottom, width, height=height, left=left, **kwargs)
#    2726     finally:
#    2727         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, bottom, width, height, left, **kwargs)
#    2283
#    2284         patches = self.bar(left=left, height=height, width=width,
# -> 2285                            bottom=bottom, orientation='horizontal', **kwargs)
# ...

# %%
labels = ["Lobster Thermador", "Baked Beans", "Crispy Bacon", 
          "Smoked Sausage", "Hannibal Ham", "Eggs", "Spam"]
values = [10, 11, 18, 19, 20, 21, 22]
positions = np.arange(len(labels))
fig = plt.figure()#initialize figure
ax = fig.add_subplot(121)#divide it into two graphs
ax.bar(positions, values, align="center")
ax.set_xticks(positions, labels)
ax = fig.add_subplot(122)
ax.barh(positions, values, align="center")
ax.set_yticks(positions, labels)
plt.show()

# %%
data = np.random.normal(size=10000)
fig, ax = plt.subplots(1, 2)
ax[0].hist(data, bins=10)
ax[1].hist(data, bins=35);

# %%
a = np.random.exponential(size=1000) + np.random.normal(size=1000) + 5
b = np.random.exponential(size=1000) + 2*np.random.normal(size=1000)
x = np.hstack((a, b, 2*np.random.normal(size=1000)))
y = np.hstack((b, a, np.random.normal(size=1000)))

# %%
fig, axes = plt.subplots(1, 2)

# %%
window = [x.min(), x.max(), y.min(), y.max()]
for ax, size in zip(axes, [10, 25]):
    ax.hexbin(x, y, gridsize=size, cmap='inferno')
    ax.axis(window)
    ax.set_aspect("equal")
#plt.hexbin()

# %%
x = np.arange(0, 50, 10)
x
# Out:
# array([ 0, 10, 20, 30, 40])

# %%
index = np.array([3, 1, 4])
index
# Out:
# array([3, 1, 4])
